# %% [markdown]
# ### Installing and importing required libraries

# %%
# !pip install seaborn
# !pip install geopandas
# !pip install sodapy
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------  7.9/8.1 MB 37.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 33.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ------------------------- -------------- 8.4/12.9 MB 39.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 38.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ----------------------------- ---------- 8.7/11.6 MB 41.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 34.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 31.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 25.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
from sodapy import Socrata
import json

# %% [markdown]
# ### Pulling data

# %%
with open("config.json") as f:
    config = json.load(f)

# %%
#First we create the client to connect with the API
client = Socrata(
    "www.datos.gov.co",
    config["socrata_api_key"],
    username=config["socrata_username"],
    password=config["socrata_password"]
)

# Performing a query once to get the full dataset
results = client.get("8hqm-7fdt", limit=175000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df = results_df.set_index('id')

# %%
results
# Out:
# [{'id': '1',
#   'entidad_que_realiza_el_registro_de_la_desaparicion': 'Instituto Nacional de Medicina Legal y Ciencias Forenses',
#   'estado_de_la_desaparicion': 'Desaparecido',
#   'clasificacion_de_la_desaparicion': 'Sin información',
#   'sexo_del_desaparecido': 'Hombre',
#   'grupo_mayor_y_menor_de_edad_del_desaparecido': 'b) Mayores de edad (>18 años)',
#   'grupo_de_edad_quinquenal_del_desaparecido': '(20 a 24)',
#   'grupo_de_edad_judicial_del_desaparecido': '(20 a 24)',
#   'ciclo_vital_del_desaparecido': '(18 a 28) Juventud',
#   'estado_civil_del_desaparecido': 'Soltero (a)',
#   'escolaridad_del_desaparecido': 'Educación básica secundaria o secundaria baja',
#   'identidad_de_genero_del_desaparecido': 'No Sabe / No Informa',
#   'orientacion_sexual_del_desaparecido': 'No Sabe / No Informa',
#   'transgenero': 'No Sabe / No Informa',
#   'pueblo_indigena_del_desaparecido': 'No aplica',
#   'pertenencia_etnica_del_desaparecido': 'Sin Pertenencia Étnica',
# ...

# %%
results_df
# Out:
#        entidad_que_realiza_el_registro_de_la_desaparicion  \
# id
# 1       Instituto Nacional de Medicina Legal y Ciencia...
# 2       Instituto Nacional de Medicina Legal y Ciencia...
# 3       Instituto Nacional de Medicina Legal y Ciencia...
# 4       Instituto Nacional de Medicina Legal y Ciencia...
# 5       Instituto Nacional de Medicina Legal y Ciencia...
# ...                                                   ...
# 174996            Fiscalía - Cuerpo Técnico Investigación
# 174997            Fiscalía - Cuerpo Técnico Investigación
# 174998            Fiscalía - Cuerpo Técnico Investigación
# 174999            Fiscalía - Cuerpo Técnico Investigación
# 175000            Fiscalía - Cuerpo Técnico Investigación
#
#        estado_de_la_desaparicion    clasificacion_de_la_desaparicion  \
# id
# 1                   Desaparecido                     Sin información
# 2                   Desaparecido                     Sin información
# ...
